# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dish_profit = 'data/catering_dish_profit.xls'
data = pd.read_excel(dish_profit,index_col="菜品名")
data = data[u'盈利'].copy()

# %%
#参数修改，降序排列
data_sorted = data.sort_values(ascending=False)
plt.figure()
data_sorted.plot(kind='bar')
plt.ylabel("盈利（元）")
p = 1.0 * data_sorted.cumsum()/data_sorted.sum()
p.plot(color='r',secondary_y=True,style='-o',linewidth=2)
plt.annotate(format(p[6],'.4%'),xy=(6,p[6]),xytext=(6*0.9,p[6]*0.9), arrowprops=dict(arrowstyle="->",connectionstyle="arc3,red=.2"))
plt.ylabel("盈利（比例）")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       6 p = 1.0 * data_sorted.cumsum()/data_sorted.sum()
#       7 p.plot(color='r',secondary_y=True,style='-o',linewidth=2)
# ----> 8 plt.annotate(format(p[6],'.4%'),xy=(6,p[6]),xytext=(6*0.9,p[6]*0.9), arrowprops=dict(arrowstyle="->",connectionstyle="arc3,red=.2"))
#       9 plt.ylabel("盈利（比例）")
#      10 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2380, in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2376 @_copy_docstring_and_deprecators(Axes.annotate)
#    2377 def annotate(
#    2378         text, xy, xytext=None, xycoords='data', textcoords=None,
#    2379         arrowprops=None, annotation_clip=None, **kwargs):
# -> 2380     return gca().annotate(
# ...
