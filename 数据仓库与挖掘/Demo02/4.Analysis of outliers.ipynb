# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
source = 'data/catering_sale.xls'
data = pd.read_excel(source, index_col = "日期")

# %%
print("数据量")
print(len(data))
print("显示数据分析大致情况")
print(data.describe())
# Out:
# 数据量
# len(data)
# 显示数据分析大致情况
# data.describe()

# %%
plt.figure()
#绘制箱型图
p = data.boxplot(return_type = 'dict')
#异常值数据
x = p['fliers'][0].get_xdata()
y = p['fliers'][0].get_ydata()
#进行排序，修改原对象
y.sort()
for i in range(len(x)):
    if i > 0:
        plt.annotate(y[i],xy=(x[i],y[i]),xytext=(x[i]+0.05-0.8/(y[i]-y[i-1]),y[i]))
    else:
        plt.annotate(y[i],xy=(x[i],y[i]),xytext=(x[i]+0.08,y[i]))
plt.show()
# Out:
# C:\Users\20887\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38144 (\N{CJK UNIFIED IDEOGRAPH-9500}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\20887\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
